# %% [markdown]
# . .venv/bin/activate
#
#
# pip install -r env/requirements.txt
#
#
# wandb login
#
#
# bsub < hpc_jobs/alex_test.sh
#
#
# bstat
#
# bqueues
#
# getquota_zhome.sh
#
#
# # interactive gpu on vs code ssh gbar
# cmd: a100sh
#
# . .venv/bin/activate
#
# module swap cuda/12.6.3

# %%
python -m src.train.train_traj_ES --config configs/traj_tptrans_full.yaml
